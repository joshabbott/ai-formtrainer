# %% [markdown]
# # My AI FormTrainer
#
# Explain stuff about how to use this
#
# Lipso Bob Loblaw yadda yadda

# %%
import cv2
import mediapipe as mp
import numpy as np

from IPython.display import Image
import pickle
import seaborn as sns
sns.set()

# import local utils
from utils.utils import *

# init mediapipe
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_pose = mp.solutions.pose

# load pretrained plank model
with open('./utils/plank_lr_trainedmodel.pkl', 'rb') as f:
    model = pickle.load(f)

# %% [markdown]
# ## Input path to your plank video
# Needs to be .mp4 and preferably edited so it's not so large

# %%
# input_filename = "./data/videos/training/joshplank-highhips.mp4"
input_filename = "./data/videos/training/joshplank-decent.mp4"
# output_filename_processed = "./joshplank-highhips_processed.mp4"

# %% [markdown]
# ## Process plank video

# %%
my_plank = ProcessPlank(mp_pose,model,input_filename)

# %%
my_plank.process_video()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# The video was successfully processed

# %% [markdown]
# ## Plot critical plank angles over time

# %%
my_plank.display_critical_angles()

# %% [markdown]
# ## Compare your average plank to an expert

# %%
my_plank.display_average_plank()
# Out:
# The mean frame was successfully processed as: meanframe.jpg

# %%
Image(filename="meanframe.jpg")

# %%
Image(filename="./data/images/youtube_expertplank.jpg")
